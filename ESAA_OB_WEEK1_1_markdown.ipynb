# %% [markdown]
# **개념 정리**

# %% [markdown]
# 선형 회귀
# - 선형 회귀 훈련 방법
#     - 직접 계산할 수 있는 공식을 사용하여 훈련 세트에 가장 잘 맞는 모델 파라미터를 해석적으로 구함
#     - 반복적인 최적화 방식인 경사 하강법을 사용하여 모델 파라미터를 조금씩 바꾸면서 비용 함수를 훈련 세트에 대해 최소화
# - 선형 회귀 모델의 예측
#     - 일반적으로 입력 특성의 가중치 합과 편향을 더해 예측을 만듦

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 선형 회귀 모델을 훈련시키려면 RMSE를 최소화 하는 𝛳를 찾아야 함
#     - 실제로는 MSE를 최소화하는 것이 더 간단!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 정규방정식: 비용함수를 최소화하는 𝛳값을 찾기 위한 해석적인 방법

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 유사역행렬은 특잇값 분해를 사용해 계산

# %% [markdown]
# 계산 복잡도
# - 일반적으로 특성 수가 두 배로 늘어나면 계산 시간이 대략 5.3에서 8배로 증가
# - LinearRegression 클래스가 사용하는 SVD 방법은 특성 수가 두 배로 늘어나면 계산 시간이 대략 4배
# - 샘플 수와 특성 수에 선형적

# %% [markdown]
# 경사 하강법: 여러 종류의 문제에서 최적의 해법을 찾을 수 있는 일반적인 최적화 알고리즘
# - 비용 함수를 최소화하기 위해 반복해서 파라미터를 조정
# - 파라미터 벡터 𝛳에 대해 비용 함수의 현재 그레이디언트를 계산 , 그레이디언트가 감소하는 방향으로 진행, 0이 되면 최소!
# - 무작위 초기화: 𝛳를 임의의 값으로 시작

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 학습률: 스텝의 크기를 결정
#     - 너무 작으면 알고리즘이 수렴하기 위해 반복을 많이 진행해야 함, 시간 오래 걸림
#     - 너무 크면 이전보다 더 높은 곳으로 올라가게 될수도 있음, 더 큰 값으로 발산
# - 경사 하강법의 문제
#     - 알고리즘이 왼쪽에서 시작하면 전역 최솟값보다 덜 좋은 지역 최솟값에 수렴
#     - 오른쪽에서 시작하면 평탄한 지역을 지나기 위해 시간이 오래 걸림
# - 블록 함수: 곡선에서 어떤 두 점을 선택해 선을 그어도 곡선을 가로지르지 않음
#     - 지역 최솟값이 없고, 전역 최솟값만 존재
#     - 연속된 함수이고 기울기가 갑자기 변하지 않음
# - 모든 특성이 같은 스케일을 갖도록 만들어야 함
# - 파라미터 공간: 비용 함수를 최소화 하는 파라미터의 조합을 찾는 공간

# %% [markdown]
# 배치 경사 하강법
# - 편도 함수: 모델 파라미터가 변경될 때 비용 함수가 얼마나 바뀌는지 계산
#     - 각각 계산하는 대신 한꺼번에 계산도 가능

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 매 경사 하강법 스텝에서 전체 훈련 세트에 대해 계산

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 위로 향하는 그레이디언트 벡터가 구해지면 반대 방향인 아래로 가야함
#     - 학습률 사용
#         - 적절한 학습률을 찾기 위해 그리드 탐색 사용
#         - 수렴하는 데 너무 오래 걸리는 모델을 막기 위해 반복 횟수 제한
#             - 그레이디언트 벡터의 노름이 허용오차보다 작아지면 알고리즘 중지

# %% [markdown]
# 확률적 경사 하강법
# - 매 스텝에서 한 개의 샘플을 무작위로 선택, 그 샘플에 대한 그레이디언트 계산
#     - 다뤄야 할 데이터가 매우 적어서 알고리즘이 훨씬 빠른
#     - 매우 큰 훈련 세트도 훈련 가능
# - 배치 경사 하강법보다 훨씬 불안정
#     - 비용 함수가 최솟값에 다다를 때까지 위아래로 요동치면서 평균적으로 감소
#     - 배치 경사 하강법보다 전역 최솟값을 찾을 가능성이 높음
# - 무작위성 딜레마를 해결하기 위해 학습률 점진적으로 감소
#     - 학습 스케줄: 매 반복에서 학습률을 결정하는 함수
#     - 학습률이 너무 빨리 줄어들면 지역 최솟값에 갇히거나 최솟값까지 가능 중간에 멈출 수 있음
# - 샘플을 무작위로 선택, 한 에포크에서 여러 번 선택될 수도 있고, 전혀 선택되지 못할 수도 있음
#     - 에포크: 각 반복을 의미

# %% [markdown]
# 미니배치 경사 하강법
# - 미니배치라 부르는 임의의 작은 샘플 세트에 대해 그레이디언트를 계산
# - 행렬 연산에 최적화된 하드웨어, 특히 GPU를 사용해서 성능 향상
# - SGD보다 최솟값에 더 가까이 도달

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 다항 회귀
# - 각 특성의 거듭제곱을 새로운 특성으로 추가, 확장된 특성을 포함한 데이터셋에 선형 모델을 훈련
# - PolynomialFeatures가 주어직 차수까지 특성 간의 모든 교차항을 추가

# %% [markdown]
# 학습 곡선
# - 훈련 세트와 검증 세트의 모델 성능을 훈련 세트 크기의 함수로 나타냄

# %% [markdown]
# 편향/분산 트레이드오프
# - 편향: 일반화 오차 중에서 편향은 잘못된 가정으로 인한 것
# - 분산: 훈련 데이터에 있는 작은 변동에 모델이 과도하게 민감하기 때문에 나타남
# - 줄일 수 없는 오차: 데이터 자체에 있는 잡음 때문에 발생

# %% [markdown]
# **코드 필사**

# %% [markdown]
# - 정규방정식

# %%
import numpy as np

X=2*np.random.rand(100,1)
y=4+3*X+np.random.randn(100,1)

# %%
X_b=np.c_[np.ones((100,1)), X] #모든 샘플에 x0=1을 추가
theta_best=np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)

# %%
theta_best
# Out:
# array([[4.4070754 ],
#        [2.83411891]])

# %%
X_new=np.array([[0], [2]])
X_new_b=np.c_[np.ones((2,1)), X_new] #모든 샘플에 x0=1을 추가
y_predict=X_new_b.dot(theta_best)
y_predict
# Out:
# array([[ 4.4070754 ],
#        [10.07531323]])

# %%
import matplotlib.pyplot as plt

plt.plot(X_new, y_predict, "r-")
plt.plot(X, y, "b.")
plt.axis([0, 2, 0, 15])
plt.show()

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(X,y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([4.4070754]), array([[2.83411891]]))

# %%
lin_reg.predict(X_new)
# Out:
# array([[ 4.4070754 ],
#        [10.07531323]])

# %%
theta_best_svd, residuals, rank, s=np.linalg.lstsq(X_b, y, rcond=1e-6)
theta_best_svd
# Out:
# array([[4.4070754 ],
#        [2.83411891]])

# %%
np.linalg.pinv(X_b).dot(y)
# Out:
# array([[4.4070754 ],
#        [2.83411891]])

# %% [markdown]
# - 배치 경사 하강법

# %%
eta=0.1 #학습률
n_iterations=1000
m=100

theta=np.random.randn(2,1) #무작위 초기화

for iterations in range(n_iterations):
    gradients=2/m*X_b.T.dot(X_b.dot(theta)-y)
    theta=theta-eta*gradients

# %%
theta
# Out:
# array([[4.4070754 ],
#        [2.83411891]])

# %% [markdown]
# - 확률적 경사 하강법

# %%
n_epochs=50
t0, t1=5, 50 #학습 스케줄 하이퍼파라미터

def learning_schedule(t):
    return t0/(t+t1)

theta=np.random.randn(2,1) #무작위 초기화

for epoch in range(n_epochs):
    for i in range(m):
        random_index=np.random.randint(m)
        xi=X_b[random_index:random_index+1]
        yi=y[random_index:random_index+1]
        gradients=2*xi.T.dot(xi.dot(theta)-yi)
        eta=learning_schedule(epoch*m+i)
        theta=theta-eta*gradients

# %%
theta
# Out:
# array([[4.40673338],
#        [2.8451418 ]])

# %%
from sklearn.linear_model import SGDRegressor
sgd_reg=SGDRegressor(max_iter=1000, tol=1e-3, penalty=None, eta0=0.1)
sgd_reg.fit(X, y.ravel())
# Out:
# SGDRegressor(eta0=0.1, penalty=None)

# %%
sgd_reg.intercept_, sgd_reg.coef_
# Out:
# (array([4.44547611]), array([2.86317134]))

# %% [markdown]
# - 다항 회귀

# %%
m=100
X=6*np.random.rand(m,1)-3
y=0.5*X**2+X+2+np.random.randn(m,1)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_features=PolynomialFeatures(degree=2, include_bias=False)
X_poly=poly_features.fit_transform(X)
X[0]
# Out:
# array([-0.98094511])

# %%
X_poly[0]
# Out:
# array([-0.98094511,  0.96225331])

# %%
lin_reg=LinearRegression()
lin_reg.fit(X_poly,y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([2.11204171]), array([[1.01422827, 0.50906787]]))

# %% [markdown]
# - 학습 곡선

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

def plot_learning_curves(model, X, y):
    X_train, X_val, y_train, y_val=train_test_split(X, y, test_size=0.2)
    train_errors, val_errors=[], []
    for m in range(1, len(X_train)):
        model.fit(X_train[:m], y_train[:m])
        y_train_predict=model.predict(X_train[:m])
        y_val_predict=model.predict(X_val)
        train_errors.append(mean_squared_error(y_train[:m], y_train_predict))
        val_errors.append(mean_squared_error(y_val, y_val_predict))
    plt.plot(np.sqrt(train_errors), "r-+", linewidth=2, label="훈련 세트")
    plt.plot(np.sqrt(val_errors), "b-", linewidth=3, label="검증 세트")

# %%
lin_reg=LinearRegression()
plot_learning_curves(lin_reg, X, y)

# %%
from sklearn.pipeline import Pipeline

polynomial_regression=Pipeline([
    ("poly_features", PolynomialFeatures(degree=10, include_bias=False)),
    ("lin_reg", LinearRegression()),
])

plot_learning_curves(polynomial_regression, X, y)
